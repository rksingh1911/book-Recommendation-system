# %% [markdown]
# # importing library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # importing dataset

# %%
data1 = pd.read_csv("C:\\Users\\91896\\Downloads\\Books.csv")
data1
# Out:
# C:\Users\91896\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
data2 = pd.read_csv("C:\\Users\\91896\\Downloads\\Ratings.csv")
data2
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
data3 = pd.read_csv("C:\\Users\\91896\\Downloads\\Users.csv")
data3
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# # EDA

# %%
list(data1)
# Out:
# ['ISBN',
#  'Book-Title',
#  'Book-Author',
#  'Year-Of-Publication',
#  'Publisher',
#  'Image-URL-S',
#  'Image-URL-M',
#  'Image-URL-L']

# %%
list(data2)
# Out:
# ['User-ID', 'ISBN', 'Book-Rating']

# %%
list(data3)
# Out:
# ['User-ID', 'Location', 'Age']

# %%
#so for data1 and data 2 ISBN is comman and data2 and data3 user id is comman so we can merge through them in one dataset

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.ndim
# Out:
# 2

# %%
data2.ndim
# Out:
# 2

# %%
data3.ndim
# Out:
# 2

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
data1.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
data3.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
data1.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
data2.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
data3.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
data3.duplicated().sum()
# Out:
# 0

# %%
data1['Book-Title'].value_counts().reset_index()
# Out:
#                                                     index  Book-Title
# 0                                          Selected Poems          27
# 1                                            Little Women          24
# 2                                       Wuthering Heights          21
# 3                                       The Secret Garden          20
# 4                                                 Dracula          20
# ...                                                   ...         ...
# 242130                         What Every Kid Should Know           1
# 242131          The Seventh Enemy (A Brady Coyne Mystery)           1
# 242132                                   A Brace of Skeet           1
# 242133  The Yellow Admiral (O'Brian, Patrick, Aubrey/M...           1
# 242134  A Guided Tour of Rene Descartes' Meditations o...           1
#
# [242135 rows x 2 columns]

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Book-Title',data = data1, order =data1['Book-Title'].value_counts().index[0:10])
plt.title("top 10 book")
# Out:
# Text(0.5, 1.0, 'top 10 book')

# %%
data1['Book-Author'].value_counts()
# Out:
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# Linda Jackson             1
# Artiste C. Arthur         1
# Emily Pearl Kingsley      1
# Jean Cassels              1
# Christopher  Biffle       1
# Name: Book-Author, Length: 102023, dtype: int64

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Book-Author',data = data1, order =data1['Book-Author'].value_counts().index[0:10])
plt.title("top 10 Book-Author")
# Out:
# Text(0.5, 1.0, 'top 10 Book-Author')

# %%
data1['Year-Of-Publication'].value_counts().reset_index()
# Out:
#     index  Year-Of-Publication
# 0    2002                13903
# 1    2001                13715
# 2    1999                13414
# 3    2000                13373
# 4    1998                12116
# ..    ...                  ...
# 197  1924                    1
# 198  2012                    1
# 199  1927                    1
# 200  1931                    1
# 201  2037                    1
#
# [202 rows x 2 columns]

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Year-Of-Publication',data = data1, order =data1['Year-Of-Publication'].value_counts().index[0:10])
plt.title("top 10 Year-Of-Publication")
# Out:
# Text(0.5, 1.0, 'top 10 Year-Of-Publication')

# %%
data1['Publisher'].value_counts().reset_index()
# Out:
#                          index  Publisher
# 0                    Harlequin       7535
# 1                   Silhouette       4220
# 2                       Pocket       3905
# 3             Ballantine Books       3783
# 4                 Bantam Books       3646
# ...                        ...        ...
# 16802           Hannover House          1
# 16803  Amber Quill Press, LLC.          1
# 16804           Lunchbox Press          1
# 16805                Ugly Town          1
# 16806                Connaught          1
#
# [16807 rows x 2 columns]

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Publisher',data = data1, order =data1['Publisher'].value_counts().index[0:10])
plt.title("top 10 Publisher")
# Out:
# Text(0.5, 1.0, 'top 10 Publisher')

# %%
print(data1['Book-Title'].nunique())
print(data1['Book-Author'].nunique())
print(data1['Year-Of-Publication'].nunique())
print(data1['Publisher'].nunique())
# Out:
# 242135
# 102023
# 202
# 16807

# %%
data2
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
data2['User-ID'].value_counts().reset_index()
# Out:
#          index  User-ID
# 0        11676    13602
# 1       198711     7550
# 2       153662     6109
# 3        98391     5891
# 4        35859     5850
# ...        ...      ...
# 105278  116180        1
# 105279  116166        1
# 105280  116154        1
# 105281  116137        1
# 105282  276723        1
#
# [105283 rows x 2 columns]

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'User-ID',data = data2, order =data2['User-ID'].value_counts().index[0:10])
plt.title("top 10 User-ID who rated book")
# Out:
# Text(0.5, 1.0, 'top 10 User-ID who rated book')

# %%
data2['ISBN'].value_counts().reset_index()
# Out:
#               index  ISBN
# 0        0971880107  2502
# 1        0316666343  1295
# 2        0385504209   883
# 3        0060928336   732
# 4        0312195516   723
# ...             ...   ...
# 340551   1568656386     1
# 340552   1568656408     1
# 340553   1569551553     1
# 340554   1570081808     1
# 340555  05162443314     1
#
# [340556 rows x 2 columns]

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'ISBN',data = data2, order =data2['ISBN'].value_counts().index[0:10])
plt.title("top 10 ISBN book")
# Out:
# Text(0.5, 1.0, 'top 10 ISBN book')

# %%
data2['Book-Rating'].value_counts().reset_index()
# Out:
#     index  Book-Rating
# 0       0       716109
# 1       8       103736
# 2      10        78610
# 3       7        76457
# 4       9        67541
# 5       5        50974
# 6       6        36924
# 7       4         8904
# 8       3         5996
# 9       2         2759
# 10      1         1770

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Book-Rating',data = data2, order =data2['Book-Rating'].value_counts().index[0:10])
plt.title("top 10 rating given by users")
# Out:
# Text(0.5, 1.0, 'top 10 rating given by users')

# %%
print(data2['User-ID'].nunique())
print(data2['ISBN'].nunique())
print(data2['Book-Rating'].nunique())
# Out:
# 105283
# 340556
# 11

# %%
data3
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
data3.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
data3['Age'].isnull().sum()
# Out:
# 110762

# %%
data3['Age'].mean()
# Out:
# 34.75143370454978

# %%
data3['Age'].hist(figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
data3['Age'].value_counts()
# Out:
# 24.0     5687
# 25.0     5618
# 26.0     5547
# 23.0     5456
# 27.0     5383
#          ...
# 168.0       1
# 132.0       1
# 159.0       1
# 186.0       1
# 127.0       1
# Name: Age, Length: 165, dtype: int64

# %%
df = pd.DataFrame(np.random.randint(20, 40, size=(110762, 1)), columns=list('A'))
print(df, '\n')
# Out:
#          A
# 0       32
# 1       35
# 2       38
# 3       31
# 4       32
# ...     ..
# 110757  20
# 110758  32
# 110759  39
# 110760  32
# 110761  25
#
# [110762 rows x 1 columns]

# %%
def fillNaN_with_unifrand(col):
    a = col.values
    m = np.isnan(a)  # mask of NaNs
    mu, sigma = col.mean(), col.std()
    a[m] = np.random.normal(mu, sigma, size=m.sum())
    return col

# %%
#fill na values
fillNaN_with_unifrand(data3['Age']).round(0)
# Out:
# 0         25.0
# 1         18.0
# 2          5.0
# 3         17.0
# 4         29.0
#           ...
# 278853    24.0
# 278854    50.0
# 278855    57.0
# 278856    13.0
# 278857    28.0
# Name: Age, Length: 278858, dtype: float64

# %%
(data3['Age']>0).any().sum()
# Out:
# 1

# %%
age = abs(data3['Age']). astype(int)
age
# Out:
# 0         24
# 1         18
# 2          5
# 3         17
# 4         29
#           ..
# 278853    23
# 278854    50
# 278855    57
# 278856    12
# 278857    27
# Name: Age, Length: 278858, dtype: int32

# %%
data3
# Out:
#         User-ID                            Location        Age
# 0             1                  nyc, new york, usa  24.650631
# 1             2           stockton, california, usa  18.000000
# 2             3     moscow, yukon territory, russia   5.378601
# 3             4           porto, v.n.gaia, portugal  17.000000
# 4             5  farnborough, hants, united kingdom  29.133430
# ...         ...                                 ...        ...
# 278853   278854               portland, oregon, usa  23.748346
# 278854   278855  tacoma, washington, united kingdom  50.000000
# 278855   278856           brampton, ontario, canada  57.492027
# 278856   278857           knoxville, tennessee, usa  12.803016
# 278857   278858                dublin, n/a, ireland  27.765386
#
# [278858 rows x 3 columns]

# %%
data3.drop('Age', axis = 1)
# Out:
#         User-ID                            Location
# 0             1                  nyc, new york, usa
# 1             2           stockton, california, usa
# 2             3     moscow, yukon territory, russia
# 3             4           porto, v.n.gaia, portugal
# 4             5  farnborough, hants, united kingdom
# ...         ...                                 ...
# 278853   278854               portland, oregon, usa
# 278854   278855  tacoma, washington, united kingdom
# 278855   278856           brampton, ontario, canada
# 278856   278857           knoxville, tennessee, usa
# 278857   278858                dublin, n/a, ireland
#
# [278858 rows x 2 columns]

# %%
data4 = data3.assign(Age=age)
data4
# Out:
#         User-ID                            Location  Age
# 0             1                  nyc, new york, usa   24
# 1             2           stockton, california, usa   18
# 2             3     moscow, yukon territory, russia    5
# 3             4           porto, v.n.gaia, portugal   17
# 4             5  farnborough, hants, united kingdom   29
# ...         ...                                 ...  ...
# 278853   278854               portland, oregon, usa   23
# 278854   278855  tacoma, washington, united kingdom   50
# 278855   278856           brampton, ontario, canada   57
# 278856   278857           knoxville, tennessee, usa   12
# 278857   278858                dublin, n/a, ireland   27
#
# [278858 rows x 3 columns]

# %%
data4['Age'].isnull().sum()
# Out:
# 0

# %%
data4['Age'].value_counts().reset_index()
# Out:
#      index   Age
# 0       29  8196
# 1       25  8189
# 2       27  8166
# 3       28  8148
# 4       26  8140
# ..     ...   ...
# 160    132     1
# 161    159     1
# 162    186     1
# 163    152     1
# 164    127     1
#
# [165 rows x 2 columns]

# %%
data3['Age'].hist(figsize = (10,8))
# Out:
# <AxesSubplot:>

# %%
data4['Location'].value_counts().reset_index()
# Out:
#                                                index  Location
# 0                    london, england, united kingdom      2506
# 1                           toronto, ontario, canada      2250
# 2                 sydney, new south wales, australia      1744
# 3                     melbourne, victoria, australia      1708
# 4                              portland, oregon, usa      1629
# ...                                              ...       ...
# 57334  gneisenaustr. 3, nordrhein-westfalen, germany         1
# 57335                             -, bayern, germany         1
# 57336                    bouchegouf, guelma, algeria         1
# 57337    indiana and philadelphia, pennsylvania, usa         1
# 57338             tacoma, washington, united kingdom         1
#
# [57339 rows x 2 columns]

# %%
data_frame = pd.DataFrame(data4.Location.str.split(",",expand=True))
data_frame
# Out:
#                   0                 1                2     3     4     5  \
# 0               nyc          new york              usa  None  None  None
# 1          stockton        california              usa  None  None  None
# 2            moscow   yukon territory           russia  None  None  None
# 3             porto          v.n.gaia         portugal  None  None  None
# 4       farnborough             hants   united kingdom  None  None  None
# ...             ...               ...              ...   ...   ...   ...
# 278853     portland            oregon              usa  None  None  None
# 278854       tacoma        washington   united kingdom  None  None  None
# 278855     brampton           ontario           canada  None  None  None
# 278856    knoxville         tennessee              usa  None  None  None
# 278857       dublin               n/a          ireland  None  None  None
#
#            6     7     8
# 0       None  None  None
# 1       None  None  None
# ...

# %%
def get_state(x):
  return x.split(',')[-1]

data4['country'] = data4['Location'].apply(get_state)

# %%
data4
# Out:
#         User-ID                            Location  Age          country
# 0             1                  nyc, new york, usa   24              usa
# 1             2           stockton, california, usa   18              usa
# 2             3     moscow, yukon territory, russia    5           russia
# 3             4           porto, v.n.gaia, portugal   17         portugal
# 4             5  farnborough, hants, united kingdom   29   united kingdom
# ...         ...                                 ...  ...              ...
# 278853   278854               portland, oregon, usa   23              usa
# 278854   278855  tacoma, washington, united kingdom   50   united kingdom
# 278855   278856           brampton, ontario, canada   57           canada
# 278856   278857           knoxville, tennessee, usa   12              usa
# 278857   278858                dublin, n/a, ireland   27          ireland
#
# [278858 rows x 4 columns]

# %%
outliar = sns.boxplot(data3['Age'])
# Out:
# C:\Users\91896\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
age_under100 = data4[data4['Age']<=100]
age_under100
# Out:
#         User-ID                            Location  Age          country
# 0             1                  nyc, new york, usa   24              usa
# 1             2           stockton, california, usa   18              usa
# 2             3     moscow, yukon territory, russia    5           russia
# 3             4           porto, v.n.gaia, portugal   17         portugal
# 4             5  farnborough, hants, united kingdom   29   united kingdom
# ...         ...                                 ...  ...              ...
# 278853   278854               portland, oregon, usa   23              usa
# 278854   278855  tacoma, washington, united kingdom   50   united kingdom
# 278855   278856           brampton, ontario, canada   57           canada
# 278856   278857           knoxville, tennessee, usa   12              usa
# 278857   278858                dublin, n/a, ireland   27          ireland
#
# [278492 rows x 4 columns]

# %%
age_data = age_under100[age_under100['Age']>=7]
age_data
# Out:
#         User-ID                            Location  Age          country
# 0             1                  nyc, new york, usa   24              usa
# 1             2           stockton, california, usa   18              usa
# 3             4           porto, v.n.gaia, portugal   17         portugal
# 4             5  farnborough, hants, united kingdom   29   united kingdom
# 5             6       santa monica, california, usa   61              usa
# ...         ...                                 ...  ...              ...
# 278853   278854               portland, oregon, usa   23              usa
# 278854   278855  tacoma, washington, united kingdom   50   united kingdom
# 278855   278856           brampton, ontario, canada   57           canada
# 278856   278857           knoxville, tennessee, usa   12              usa
# 278857   278858                dublin, n/a, ireland   27          ireland
#
# [274850 rows x 4 columns]

# %%
age_data.isnull().sum()
# Out:
# User-ID     0
# Location    0
# Age         0
# country     0
# dtype: int64

# %%
age_data['country'].value_counts()
# Out:
#  usa                137660
#  canada              21343
#  united kingdom      18276
#  germany             16785
#  spain               13064
#                      ...
#  carter                  1
#  usa & canada            1
#  p.r.china               1
#  none                    1
#  united kingdom.         1
# Name: country, Length: 695, dtype: int64

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'country',data = age_data, order =age_data['country'].value_counts().index[0:10])
plt.title("number of readers")
# Out:
# Text(0.5, 1.0, 'number of readers')

# %%
age_data['Age'].value_counts()
# Out:
# 29    8196
# 25    8189
# 27    8166
# 28    8148
# 26    8140
#       ...
# 97       4
# 96       3
# 88       3
# 95       2
# 98       2
# Name: Age, Length: 94, dtype: int64

# %%
plt.figure(figsize = (15,6))
sns.countplot(y = 'Age',data = age_data, order =age_data['Age'].value_counts().index[0:10])
plt.title("top most 10 people age in the dataset")
# Out:
# Text(0.5, 1.0, 'top most 10 people age in the dataset')

# %% [markdown]
# # merge data1 and data2 set

# %%
Books_rating = data2.merge(data1,on='ISBN')
Books_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
Books_rating.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            4
# dtype: int64

# %%
Books_rating.dropna(inplace=True)
Books_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
Books_rating.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
books = data4.merge(Books_rating,on='User-ID')
books
# Out:
#          User-ID                   Location  Age  country        ISBN  \
# 0              2  stockton, california, usa   18      usa  0195153448
# 1              8   timmins, ontario, canada   60   canada  0002005018
# 2              8   timmins, ontario, canada   60   canada  0060973129
# 3              8   timmins, ontario, canada   60   canada  0374157065
# 4              8   timmins, ontario, canada   60   canada  0393045218
# ...          ...                        ...  ...      ...         ...
# 1031124   278854      portland, oregon, usa   23      usa  0375703063
# 1031125   278854      portland, oregon, usa   23      usa  0316184152
# 1031126   278854      portland, oregon, usa   23      usa  0425163393
# 1031127   278854      portland, oregon, usa   23      usa  0553275739
# 1031128   278854      portland, oregon, usa   23      usa  0553578596
#
#          Book-Rating                                         Book-Title  \
# ...

# %%
books['User-ID'].value_counts()
# Out:
# 11676     11144
# 198711     6456
# 153662     5814
# 98391      5777
# 35859      5646
#           ...
# 119065        1
# 119082        1
# 119085        1
# 119095        1
# 139230        1
# Name: User-ID, Length: 92106, dtype: int64

# %%
books['Book-Rating'].value_counts()
# Out:
# 0     647291
# 8      91803
# 10     71225
# 7      66401
# 9      60776
# 5      45355
# 6      31687
# 4       7617
# 3       5118
# 2       2375
# 1       1481
# Name: Book-Rating, dtype: int64

# %%
#!pip install dtale

# %%
#import dtale
#eda = dtale.show(books)

# %% [markdown]
# # Popularity Based Recommender System

# %%
num_rating_df = books.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241061                                      Ã?Â?lpiraten.            2
# 241062                     Ã?Â?rger mit Produkt X. Roman.            4
# 241063                                Ã?Â?sterlich leben.            1
# 241064                              Ã?Â?stlich der Berge.            3
# 241065                                  Ã?Â?thique en toc            2
#
# [241066 rows x 2 columns]

# %%
avg_rating_df = books.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241061                                      Ã?Â?lpiraten.    0.000000
# 241062                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241063                                Ã?Â?sterlich leben.    7.000000
# 241064                              Ã?Â?stlich der Berge.    2.666667
# 241065                                  Ã?Â?thique en toc    4.000000
#
# [241066 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241061                                      Ã?Â?lpiraten.            2
# 241062                     Ã?Â?rger mit Produkt X. Roman.            4
# 241063                                Ã?Â?sterlich leben.            1
# 241064                              Ã?Â?stlich der Berge.            3
# 241065                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                               Book-Title  \
# 0      Harry Potter and the Prisoner of Azkaban (Book 3)
# 428         Harry Potter and the Goblet of Fire (Book 4)
# 815       Harry Potter and the Sorcerer's Stone (Book 1)
# 1093   Harry Potter and the Order of the Phoenix (Boo...
# 1440    Harry Potter and the Chamber of Secrets (Book 2)
# 1996   The Hobbit : The Enchanting Prelude to The Lor...
# 2277   The Fellowship of the Ring (The Lord of the Ri...
# 2645   Harry Potter and the Sorcerer's Stone (Harry P...
# 3220      The Two Towers (The Lord of the Rings, Part 2)
# 3480                               To Kill a Mockingbird
# 3990                                   The Da Vinci Code
# 4888                  The Five People You Meet in Heaven
# 5318                              The Catcher in the Rye
# 5767                           The Lovely Bones: A Novel
# 7062                                                1984
# ...

# %%
#popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136369.01.MZZZZZZZ.jpg'

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
x = books.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = books[books['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]
